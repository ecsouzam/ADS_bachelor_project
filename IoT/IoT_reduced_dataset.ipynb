# %%
import pandas as pd

df_iot = pd.read_csv(r"D:\BPS\dataset\IoT\iot_benign_ddos_full.csv")

# Selected features according to results
selected_features = [
    "Total Bwd packets",
    "Total Length of Bwd Packet",
    "Fwd Packet Length Min",
    "Bwd Packet Length Max",
    "Flow Packets/s",
    "Flow IAT Std",
    "Flow IAT Min",
    "Fwd IAT Std",
    "Fwd Packets/s",
    "Bwd Packets/s",
    "Packet Length Max",
    "Packet Length Mean",
    "RST Flag Count",
    "Average Packet Size",
    "Bwd Segment Size Avg",
    "Subflow Fwd Packets",
    "Subflow Fwd Bytes",
    "Fwd Seg Size Min",
    "Idle Min"
]

# new reduzed dataset and traffic class target
df_iot_reduced = df_iot[selected_features + ["traffic_class"]]


df_iot_reduced.to_csv(
    r"D:\BPS\dataset\IoT\iot_benign_ddos_reduced.csv",
    index=False
)

print(df_iot_reduced.head())
print(df_iot_reduced.shape)
# Out:
#    Total Bwd packets  Total Length of Bwd Packet  Fwd Packet Length Min  \
# 0                  4                       375.0                    0.0
# 1                  4                         7.0                    0.0
# 2                  4                       375.0                    0.0
# 3                  4                         7.0                    0.0
# 4                  4                       375.0                    0.0
#
#    Bwd Packet Length Max  Flow Packets/s  Flow IAT Std  Flow IAT Min  \
# 0                  375.0       30.826246  57448.362362           1.0
# 1                    7.0       30.893862  57258.196618           1.0
# 2                  375.0       30.744110  57576.745941           1.0
# 3                    7.0       30.779964  57456.509783           1.0
# 4                  375.0       30.690328  57668.090815           0.0
#
#     Fwd IAT Std  Fwd Packets/s  Bwd Packets/s  Packet Length Max  \
# ...
